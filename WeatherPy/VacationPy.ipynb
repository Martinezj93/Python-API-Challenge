# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  puerto ayora  -0.7393  -90.3518     23.08        94          48
# 1        1         bluff -46.6000  168.3333     15.39        85          75
# 2        2   deputatskiy  69.3000  139.9000    -38.25       100          58
# 3        3       mataura -46.1927  168.8643     13.23        85          86
# 4        4    bredasdorp -34.5322   20.0403     26.04        55          63
#
#    Wind Speed Country        Date
# 0        0.57      EC  1677582119
# 1        2.46      NZ  1677582120
# 2        1.45      RU  1677582121
# 3        0.80      NZ  1677582121
# 4        5.05      ZA  1677582121

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    scale = 1,
    color = "City"
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
favorite_weather = city_data_df.loc[(city_data_df["Max Temp"] > 22) & (city_data_df["Max Temp"] < 30) &
                                    (city_data_df["Wind Speed"] < 5) & (city_data_df["Cloudiness"] == 0)]

# Display sample data
favorite_weather
# Out:
#      City_ID                          City      Lat       Lng  Max Temp  \
# 6          6                     busselton -33.6500  115.3333     27.04
# 15        15                           sur  22.5667   59.5289     27.71
# 16        16                      ajdabiya  30.7554   20.2263     25.61
# 19        19                          tura  25.5198   90.2201     27.09
# 68        68                        palasa  18.7667   84.4167     28.90
# 122      122                         tahta  26.7693   31.5021     29.16
# 127      127                     guarapari -20.6667  -40.4975     26.05
# 167      167                         moron -34.6534  -58.6198     26.55
# 183      183                        mehran  33.1222   46.1646     25.24
# 192      192                    vila velha -20.3297  -40.2925     26.08
# 217      217                      araouane  18.9048   -3.5265     26.45
# 256      256                         sohag  26.5570   31.6948     29.84
# 283      283                    alexandria  31.2156   29.9553     22.65
# 298      298                  bahia blanca -38.7196  -62.2724     22.94
# 303      303                         pisco -13.7000  -76.2167     22.03
# 325      325                     taoudenni  22.6783   -3.9836     24.68
# 481      481                     encantado -29.2361  -51.8697     23.11
# 486      486                     sirajganj  24.4500   89.7167     27.20
# 554      554  presidencia roque saenz pena -26.7852  -60.4388     22.24
#
#      Humidity  Cloudiness  Wind Speed Country        Date
# 6          44           0        4.50      AU  1677582013
# 15         45           0        2.54      OM  1677582127
# 16         25           0        1.92      LY  1677582128
# 19         22           0        2.49      IN  1677582129
# 68         41           0        4.77      IN  1677582157
# 122         9           0        0.56      EG  1677582187
# 127        73           0        1.72      BR  1677582190
# 167        73           0        2.66      AR  1677582214
# 183        22           0        4.76      IR  1677582223
# 192        90           0        1.68      BR  1677582227
# 217        15           0        3.28      ML  1677582242
# 256         8           0        1.41      EG  1677582262
# 283        49           0        3.79      EG  1677582007
# 298        38           0        0.45      AR  1677582283
# 303        78           0        2.06      PE  1677582286
# 325        19           0        2.72      ML  1677582297
# 481        75           0        1.33      BR  1677582380
# 486        39           0        2.82      BD  1677582382
# 554        83           0        2.87      AR  1677582414

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = pd.DataFrame(favorite_weather[["City", "Country", "Lat", "Lng", "Humidity"]])

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                              City Country      Lat       Lng  Humidity  \
# 6                       busselton      AU -33.6500  115.3333        44
# 15                            sur      OM  22.5667   59.5289        45
# 16                       ajdabiya      LY  30.7554   20.2263        25
# 19                           tura      IN  25.5198   90.2201        22
# 68                         palasa      IN  18.7667   84.4167        41
# 122                         tahta      EG  26.7693   31.5021         9
# 127                     guarapari      BR -20.6667  -40.4975        73
# 167                         moron      AR -34.6534  -58.6198        73
# 183                        mehran      IR  33.1222   46.1646        22
# 192                    vila velha      BR -20.3297  -40.2925        90
# 217                      araouane      ML  18.9048   -3.5265        15
# 256                         sohag      EG  26.5570   31.6948         8
# 283                    alexandria      EG  31.2156   29.9553        49
# 298                  bahia blanca      AR -38.7196  -62.2724        38
# 303                         pisco      PE -13.7000  -76.2167        78
# 325                     taoudenni      ML  22.6783   -3.9836        19
# 481                     encantado      BR -29.2361  -51.8697        75
# 486                     sirajganj      BD  24.4500   89.7167        39
# 554  presidencia roque saenz pena      AR -26.7852  -60.4388        83
#
#     Hotel Name
# 6
# 15
# 16
# 19
# 68
# 122
# 127
# 167
# 183
# 192
# 217
# 256
# 283
# 298
# 303
# 325
# 481
# 486
# 554

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lng = hotel_df.loc[index, "Lng"]
    lat = hotel_df.loc[index, "Lat"]

    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places?"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
   
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# busselton - nearest hotel: Broadwater Beach Resort
# sur - nearest hotel: Sur Hotel
# ajdabiya - nearest hotel: فندق المدينة
# tura - nearest hotel: No hotel found
# palasa - nearest hotel: No hotel found
# tahta - nearest hotel: No hotel found
# guarapari - nearest hotel: Osmar Hotel
# moron - nearest hotel: La Esquina
# mehran - nearest hotel: No hotel found
# vila velha - nearest hotel: Hotel Prainha
# araouane - nearest hotel: No hotel found
# sohag - nearest hotel: Al Safa Hotel
# alexandria - nearest hotel: Smoha Zahran Haus (7th floor)
# bahia blanca - nearest hotel: Hotel Austral Bahía
# pisco - nearest hotel: La Portada
# taoudenni - nearest hotel: No hotel found
# encantado - nearest hotel: Hotel Girardi
# sirajganj - nearest hotel: Purbani
# presidencia roque saenz pena - nearest hotel: Hotel Presidente
#                              City Country      Lat       Lng  Humidity  \
# 6                       busselton      AU -33.6500  115.3333        44
# 15                            sur      OM  22.5667   59.5289        45
# 16                       ajdabiya      LY  30.7554   20.2263        25
# 19                           tura      IN  25.5198   90.2201        22
# 68                         palasa      IN  18.7667   84.4167        41
# 122                         tahta      EG  26.7693   31.5021         9
# 127                     guarapari      BR -20.6667  -40.4975        73
# 167                         moron      AR -34.6534  -58.6198        73
# 183                        mehran      IR  33.1222   46.1646        22
# 192                    vila velha      BR -20.3297  -40.2925        90
# 217                      araouane      ML  18.9048   -3.5265        15
# 256                         sohag      EG  26.5570   31.6948         8
# 283                    alexandria      EG  31.2156   29.9553        49
# 298                  bahia blanca      AR -38.7196  -62.2724        38
# 303                         pisco      PE -13.7000  -76.2167        78
# 325                     taoudenni      ML  22.6783   -3.9836        19
# 481                     encantado      BR -29.2361  -51.8697        75
# 486                     sirajganj      BD  24.4500   89.7167        39
# 554  presidencia roque saenz pena      AR -26.7852  -60.4388        83
#
#                         Hotel Name
# 6          Broadwater Beach Resort
# 15                       Sur Hotel
# 16                    فندق المدينة
# 19                  No hotel found
# 68                  No hotel found
# 122                 No hotel found
# 127                    Osmar Hotel
# 167                     La Esquina
# 183                 No hotel found
# 192                  Hotel Prainha
# 217                 No hotel found
# 256                  Al Safa Hotel
# 283  Smoha Zahran Haus (7th floor)
# 298            Hotel Austral Bahía
# 303                     La Portada
# 325                 No hotel found
# 481                  Hotel Girardi
# 486                        Purbani
# 554               Hotel Presidente

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    scale = 1.5,
    color = "City",
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
